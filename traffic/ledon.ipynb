# %%
import json, time
from boltiot import Sms, Bolt
import random
import time

API_KEY = 'c855a48b-9092-4374-a91c-bb0745f2f4c0'
DEVICE_ID = 'BOLT7421046'

mybolt = Bolt(API_KEY, DEVICE_ID)

# %%
'''
count=0
while count<=3:
    response = mybolt.analogRead('A0') 
    data = json.loads(response) 
    x=int(data['value'])
    print(x)

    if x>60:
        mybolt.digitalWrite(1,'HIGH')
    else:
        mybolt.digitalWrite(1,'LOW')
    count+=1
    time.sleep(5)
    

if x>300:
    mybolt.digitalWrite(1,'HIGH')
else:
    mybolt.digitalWrite(1,'LOW')
'''   
import json, time
from boltiot import Sms, Bolt
import json, time

SID = 'AC393a58a67e6fd42291a45c0de298df7d' 
AUTH_TOKEN = '4752733f679570a5cac3df34973cc613' 
FROM_NUMBER = '(605) 413-1584'
TO_NUMBER = '+917742874654'
API_KEY = '81abccbd-f13e-41b1-993b-04cb120c6ea0'
DEVICE_ID = 'BOLT7421046'

minimum_limit = 400
maximum_limit = 600  


mybolt = Bolt(API_KEY, DEVICE_ID)
sms = Sms(SID, AUTH_TOKEN, TO_NUMBER, FROM_NUMBER)
response = sms.send_sms("The Current temperature sensor value is " )

# %%
'''
count=0
while count<=3:
    response = mybolt.analogRead('A0') 
    data = json.loads(response) 
    x=int(data['value'])
    print(x)

    if x<60:
        mybolt.digitalWrite(2,'HIGH')
    else:
        mybolt.digitalWrite(2,'LOW')
    count+=1
    time.sleep(5)
    
    
#mybolt.digitalWrite(4,'HIGH')
'''

# %%
import cv2 
  

# capture frames from a video  
car_cascade = cv2.CascadeClassifier('cars.xml')
maxcar=max=0
movement=1
while movement<=10:
    f="car"+str(random.choice([1, 2, 3, 4, 5, 6]))+".jpg"
    #print(f)
    frame=cv2.imread(f)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    # Detects cars of different sizes in the input image 
    cars = car_cascade.detectMultiScale(gray, 1.1, 1) 
    count=0
    # To draw a rectangle in each cars 
    for (x,y,w,h) in cars: 
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2) 
        count+=1
    # Display frames in a window  
    cv2.imshow('TRAFFIC'+str(movement), frame)
    print(f,count)
    cv2.waitKey(1)
    '''
    if count>=4:
        mybolt.digitalWrite(0,"HIGH")
    else:
        mybolt.digitalWrite(0,"LOW")  '''
    if count<4:
        print("LOW TRAFFIC")
    if count>=4 and count<8:
        print("HIGH TRAFFIC")
    if count>=8:
        print("ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>")
    time.sleep(5)
    cv2.destroyAllWindows()
    movement+=1
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# car5.jpg 8
# ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>
# car5.jpg 8
# ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>
# car2.jpg 9
# ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>
# car2.jpg 9
# ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>
# car5.jpg 8
# ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>
# car2.jpg 9
# ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>
# car1.jpg 4
# HIGH TRAFFIC
# car4.jpg 1
# LOW TRAFFIC
# car5.jpg 8
# ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>
# car2.jpg 9
# ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>

# %%
import cv2 
  
SID = 'AC393a58a67e6fd42291a45c0de298df7d' 
AUTH_TOKEN = '4752733f679570a5cac3df34973cc613' 
FROM_NUMBER = '(605) 413-1584'
TO_NUMBER = '+917742874654'
sms = Sms(SID, AUTH_TOKEN, TO_NUMBER, FROM_NUMBER)

# capture frames from a video  
car_cascade = cv2.CascadeClassifier('cars.xml')
maxcar=max=0
movement=1
while movement<=10:
    f="car"+str(random.choice([1, 2, 3, 4, 5, 6]))+".jpg"
    #print(f)
    frame=cv2.imread(f)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
    # Detects cars of different sizes in the input image 
    cars = car_cascade.detectMultiScale(gray, 1.1, 1) 
    count=0
    # To draw a rectangle in each cars 
    for (x,y,w,h) in cars: 
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2) 
        count+=1
    # Display frames in a window  
    cv2.imshow('TRAFFIC'+str(movement), frame)
    print(f,count)
    cv2.waitKey(1)
    if count>=4:
        mybolt.digitalWrite(4,"HIGH")
    else:
        mybolt.digitalWrite(4,"LOW")
    if count<4:
        print("LOW TRAFFIC")
    if count>=4 and count<8:
        print("HIGH TRAFFIC")
    if count>=8:
        print("ALERT!!!!!!!!! <<<<<<< TRAFFIC JAM >>>>>>")
        sms = Sms(SID, AUTH_TOKEN, TO_NUMBER, FROM_NUMBER)
        s="HIGH TRAFFIC IN ROAD"
        res = sms.send_sms(s)
    
    response = mybolt.analogRead('A0') 
    data = json.loads(response) 
    x=int(data['value'])
    print(x)

    if x<100:
        mybolt.digitalWrite(1,'HIGH')
    else:
        mybolt.digitalWrite(1,'LOW')
    
        
    time.sleep(5)
    cv2.destroyAllWindows()
    movement+=1
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# car3.jpg 2
# LOW TRAFFIC
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-8330dfbcf4e8> in <module>
#      42
#      43     response = mybolt.analogRead('A0')
# ---> 44     data = json.loads(response)
#      45     x=int(data['value'])
#      46     print(x)
#
# D:\Anaconda\envs\opencv-env\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346         if not isinstance(s, (bytes, bytearray)):
#     347             raise TypeError('the JSON object must be str, bytes or bytearray, '
# --> 348                             'not {!r}'.format(s.__class__.__name__))
#     349         s = s.decode(detect_encoding(s), 'surrogatepass')
#     350
#
# TypeError: the JSON object must be str, bytes or bytearray, not 'dict'

# %%
import cv2 
  
# capture frames from a video  
car_cascade = cv2.CascadeClassifier('cars.xml')
maxcar=max=0
movement=1
while movement<=10:
    
    f1="car"+random.choice([1, 2, 3, 4, 5, 6])
    f2="car"+random.choice([1, 2, 3, 4, 5, 6])
    frame2=cv2.imread('C:\\Users\\hp\\Desktop\\traffic\\car5.jpg')
    frame1=cv2.imread('C:\\Users\\hp\\Desktop\\traffic\\car4.jpg')
    
    gray1 = cv2.cvtColor(frame1, cv2.COLOR_BGR2GRAY) 
    
    gray2 = cv2.cvtColor(frame2, cv2.COLOR_BGR2GRAY) 
    
    # Detects cars of different sizes in the input image 
    cars1 = car_cascade.detectMultiScale(gray1, 1.1, 1) 
    cars2 = car_cascade.detectMultiScale(gray2, 1.1, 1) 
    
    count1=0
    count2=0
    # To draw a rectangle in each cars 
    for (x,y,w,h) in cars1: 
        cv2.rectangle(frame1,(x,y),(x+w,y+h),(0,0,255),2) 
        count1+=1
    for (a,b,c,d) in cars2: 
        cv2.rectangle(frame2,(a,b),(a+c,b+d),(0,0,255),2) 
        count2+=1
    # Display frames in a window  
    cv2.imshow('video2', frame1) 
    cv2.imshow('video1', frame2) 
    print(count1," : ",count2)
    movement+=1
    if count1>count2:
        print("ROAD 1 ON !")
        mybolt.digitaMultilWrite(0,'HIGH')
        
    else:
        print("ROAD 2 ON !")
        mybolt.digitalMultiWrite(1,'HIGH')

cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e5efc51194aa> in <module>
#       7 while movement<=10:
#       8
# ----> 9     f1="car"+random.choice([1, 2, 3, 4, 5, 6])
#      10     f2="car"+random.choice([1, 2, 3, 4, 5, 6])
#      11     frame2=cv2.imread('C:\\Users\\hp\\Desktop\\traffic\\car5.jpg')
#
# TypeError: must be str, not int
